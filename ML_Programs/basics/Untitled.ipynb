# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import accuracy_score,confusion_matrix
from sklearn.cluster import KMeans

# %%
d=pd.read_csv('C:/Users/zaidb/OneDrive/Desktop/Program/ML_Programs/datasets/iris.csv')

# %%
x=d.iloc[:,[0,1,2,3]].values

# %%
sns.pairplot(d)

# %%
Elbow=[]
for i in range(1,11):
    kmeans=KMeans(n_clusters=i,init="k-means++",max_iter=300,random_state=20)
    kmeans.fit(x)
    Elbow.append(kmeans.inertia_)

# %%
plt.plot(range(1,11),Elbow,marker='o')
plt.title("e met")
plt.xlabel("nc")
plt.ylabel("elb")
plt.show()

# %%
kmeans=KMeans(n_clusters=3,init="k-means++",max_iter=300,n_init=10,random_state=0)
y_kmeans=kmeans.fit_predict(x)

# %%
plt.scatter(x[y_kmeans == 0,0],x[y_kmeans == 0,1],s=100,c='red',label='se')
plt.scatter(x[y_kmeans == 1,0],x[y_kmeans == 1,1],s=100,c='blue',label='ve')
plt.scatter(x[y_kmeans == 2,0],x[y_kmeans == 2,1],s=100,c='green',label='vi')
plt.scatter(kmeans_cluster_centers_[:,0],)

# %%
# Out:
# AdaBoostClassifier(learning_rate=0.2, n_estimators=100)

# %%
# Out:
# RandomForestClassifier()

# %%
ypr1=sin.predict(xte)

# %%
arf=accuracy_score(yte,ypr)*100
print(arf)
# Out:
# 97.36842105263158

# %%
cm1=confusion_matrix(yte,ypr1)
print(cm1)
# Out:
# [[13  0  0]
#  [ 0 15  1]
#  [ 0  0  9]]

# %%
fig,ax=plt.subplots(figsize=(6,5))
ax.imshow(cm1)
ax.grid(False)
ax.xaxis.set(ticks=(0,1,2),ticklabels=('p s','p ve','p vi'))
ax.yaxis.set(ticks=(0,1,2),ticklabels=('a s','a ve','a vi'))
ax.set_ylim(2.5,-0.5)
for i in range(3):
    for j in range(3):
        ax.text(j,i,cm[i,j],ha='center',va='center',c='white')
plt.show()
