# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix,accuracy_score
from sklearn.cluster import AgglomerativeClustering
from scipy.cluster.hierarchy import fcluster, linkage, dendrogram

# %%
dataset = pd.read_csv('C:/Users/zaidb/OneDrive/Desktop/Program/ML_Programs/datasets/iris.csv')

# %%
x = dataset.iloc[:, [0,1,2,3]].values

# %%
d_m=linkage(x,method="ward",metric="euclidean")

# %%
dn=dendrogram(d_m)

# %%
dn=dendrogram(d_m)
plt.axhline(y=13,c='red',linestyle='--')
plt.ylim(0,15)
plt.show()

# %%
agg=AgglomerativeClustering(n_clusters=3,affinity="euclidean",linkage="ward")
agg.fit_predict(x)
plt.title("agg-3")
plt.scatter(x[:,2],x[:,3],c=cluster.labels_,label=cluster.labels_)
plt.xlabel("pl")
plt.ylabel("pw")
# Out:
# /Users/rahul/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_agglomerative.py:1005: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 4
#       2 agg.fit_predict(x)
#       3 plt.title("agg-3")
# ----> 4 plt.scatter(x[:,2],x[:,3],c=cluster.labels_,label=cluster.labels_)
#       5 plt.xlabel("pl")
#       6 plt.ylabel("pw")
#
# NameError: name 'cluster' is not defined
