# %%
Aim: To identify relationships between iris data set

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
dataset=pd.read_csv("C:/Users/zaidb/OneDrive/Desktop/Program/ML_Programs/datasets/iris.csv")
print(dataset)
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %%
print(dataset.to_string)
# Out:
# <bound method DataFrame.to_string of      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]>

# %%
print(dataset.head)
# Out:
# <bound method NDFrame.head of      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]>

# %%
x=dataset.iloc[:,0].values
y=dataset.iloc[:,4].values

# %%
plt.scatter(x,y)
plt.xlabel("sepal length")
plt.ylabel("iris class")
plt.show()

# %%
x=dataset.iloc[:,1].values
y=dataset.iloc[:,4].values

# %%
plt.scatter(x,y)
plt.xlabel("sepal widthth")
plt.ylabel("iris class")
plt.show()

# %%
x=dataset.iloc[:,2].values
y=dataset.iloc[:,4].values

# %%
plt.scatter(x,y)
plt.xlabel("petal length")
plt.ylabel("iris class")
plt.show()

# %%
x=dataset.iloc[:,3].values
y=dataset.iloc[:,4].values

# %%
plt.scatter(x,y)
plt.xlabel("petal widtth")
plt.ylabel("iris class")
plt.show()
